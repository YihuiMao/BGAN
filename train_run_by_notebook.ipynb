# %%
 ! pip install -q kaggle

# %%
 from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-6737c6fc-d723-4ebb-89f0-367cfc733742" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6737c6fc-d723-4ebb-89f0-367cfc733742">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json
# {'kaggle.json': b'{"username":"maoyihui19890503","key":"24805cda35b57921ba645f85e7d0b911"}'}

# %%
 ! mkdir ~/.kaggle

# %%
 ! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ...
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              237KB  2021-12-12 11:59:54          17976
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01          10702
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19           5338
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   2GB  2021-10-22 10:48:21           3842
# ...

# %%
! kaggle datasets download -d balraj98/edges2shoes-dataset
# Out:
# ...
# 100% 2.03G/2.04G [00:37<00:00, 43.3MB/s]
# 100% 2.04G/2.04G [00:37<00:00, 59.0MB/s]

# %%
! mkdir data

# %%
! unzip edges2shoes-dataset.zip -d data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/train/5681_AB.jpg
#   inflating: data/train/5682_AB.jpg
#   inflating: data/train/5683_AB.jpg
#   inflating: data/train/5684_AB.jpg
#   inflating: data/train/5685_AB.jpg
#   inflating: data/train/5686_AB.jpg
#   inflating: data/train/5687_AB.jpg
#   inflating: data/train/5688_AB.jpg
#   inflating: data/train/5689_AB.jpg
#   inflating: data/train/568_AB.jpg
#   inflating: data/train/5690_AB.jpg
#   inflating: data/train/5691_AB.jpg
#   inflating: data/train/5692_AB.jpg
#   inflating: data/train/5693_AB.jpg
#   inflating: data/train/5694_AB.jpg
#   inflating: data/train/5695_AB.jpg
#   inflating: data/train/5696_AB.jpg
#   inflating: data/train/5697_AB.jpg
#   inflating: data/train/5698_AB.jpg
#   inflating: data/train/5699_AB.jpg
#   inflating: data/train/569_AB.jpg
#   inflating: data/train/56_AB.jpg
#   inflating: data/train/5700_AB.jpg
#   inflating: data/train/5701_AB.jpg
#   inflating: data/train/5702_AB.jpg
# ...

# %%
import shutil

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-610a559929b4> in <module>()
# ----> 1 shutil.rmtree('./image_demo_1')
#
# /usr/lib/python3.7/shutil.py in rmtree(path, ignore_errors, onerror)
#     483             orig_st = os.lstat(path)
#     484         except Exception:
# --> 485             onerror(os.lstat, path, sys.exc_info())
#     486             return
#     487         try:
#
# /usr/lib/python3.7/shutil.py in rmtree(path, ignore_errors, onerror)
#     481         # lstat()/open()/fstat() trick.
#     482         try:
# --> 483             orig_st = os.lstat(path)
#     484         except Exception:
#     485             onerror(os.lstat, path, sys.exc_info())
#
# FileNotFoundError: [Errno 2] No such file or directory: './image_demo_1'

# %%
# !python train.py
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:01<00:00, 41.6MB/s]
# -------------------
# iter 0   3.4856441020965576 11.524415969848633 0.42759960889816284
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
#!zip -r image_input.zip image_input

# %%
#from google.colab import files



#files.download('example_dists.txt')

# %%
# !pip install pytorch-fid

# %%
! python -m pytorch_fid ./image_rgb ./image_sample

# %%
# !pip install lpips

# %%
# !git clone https://github.com/richzhang/PerceptualSimilarity

# %%
cd PerceptualSimilarity

# %%
# !python lpips_2dirs.py -d0 ../image_rgb -d1 ../image_sample/ -o imgs/example_dists.txt --use_gpu
